# %%
# !pwd
# Out:
# /home/jlcunningham/GEOG-288KC-geospatial-foundation-models/James scripts

# %%
import geogfm
geogfm.verify_environment()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 import geogfm
# ----> 2 geogfm.verify_environment()
#
# AttributeError: module 'geogfm' has no attribute 'verify_environment'

# %%
import geogfm
print(geogfm.__file__)
# Out:
# /home/g288kc/geoAI/geogfm/__init__.py

# %%
import geogfm

# %%
dir(geogfm)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__']

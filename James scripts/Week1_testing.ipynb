# %%
# !pwd
# Out:
# /home/jlcunningham/GEOG-288KC-geospatial-foundation-models

# %%
# !pip install -e .
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Obtaining file:///home/jlcunningham/GEOG-288KC-geospatial-foundation-models
#   Installing build dependencies ... one
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... one
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#   Building editable for geogfm (pyproject.toml) ... one
#   Created wheel for geogfm: filename=geogfm-0.1.0-0.editable-py3-none-any.whl size=7109 sha256=7df480e66827ed8ee9e515f36bada0ca035c680e829cdc1e14c8f35e2b80c124
#   Stored in directory: /tmp/pip-ephem-wheel-cache-39qeqjvz/wheels/86/33/7c/6a8af51f351fafe3e05d26c7c614505381b2cf24bc7ec56c7a
# Successfully built geogfm
# ...

# %%
import geogfm

# %%
dir(geogfm)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'c01',
#  'calculate_band_statistics',
#  'calculate_ndvi',
#  'create_rgb_composite',
#  'create_scene_tiles',
#  'export_analysis_results',
#  'get_scene_info',
#  'get_subset_from_scene',
#  'load_sentinel2_bands',
#  'load_week1_data',
#  'normalize_band',
#  'plot_band_comparison',
#  'save_geotiff',
#  'search_STAC_scenes',
#  'search_sentinel2_scenes',
#  'setup_planetary_computer_auth',
#  'test_subset_functionality',
#  'verify_environment']

# %%
from geogfm import load_sentinel2_bands

# %%
from geogfm import c01

# %%
required_packages = [
    'rasterio', 'xarray', 'torch', 'transformers',
    'folium', 'matplotlib', 'numpy', 'pandas',
    'pystac-client', 'geopandas', 'rioxarray', 'planetary-computer'
]

geogfm.verify_environment(required_packages)
# Out:
# 2025-10-08 13:04:09,445 - INFO - ✅ All 12 packages verified
# {'rasterio': '1.3.9',
#  'xarray': '2023.10.1',
#  'torch': '2.8.0',
#  'transformers': '4.55.4',
#  'folium': '0.20.0',
#  'matplotlib': '3.7.3',
#  'numpy': '1.24.4',
#  'pandas': '2.1.4',
#  'pystac-client': '0.9.0',
#  'geopandas': '0.14.4',
#  'rioxarray': '0.15.7',
#  'planetary-computer': '1.0.0'}

# %%
#put quickstart stuff into a notebook to step 5? or section 2... then save that then, import that?
#then run through all the rest of week 1 steps to see outputs.
